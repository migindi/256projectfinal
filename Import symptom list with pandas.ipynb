# %%
import html5lib

'''
with open("mydocument.html", "rb") as f:
    document = html5lib.parse(f)
'''
# Out:
# '\nwith open("mydocument.html", "rb") as f:\n    document = html5lib.parse(f)\n'

# %%
import pandas as pd
import numpy as np

# this turns off warning messages
import warnings
warnings.filterwarnings('ignore')

symptoms = pd.read_csv('sympton ID list.csv')
symptoms.sample(1178)
# Out:
#                                     Abdominal guarding   s_1558) Unnamed: 2  \
# 610                                 Impulsive behavior   s_1384)        NaN
# 210                                 Cold feet and toes    s_408)        NaN
# 357                              Drooping mouth corner    s_432)        NaN
# 335                       Discharge in tympanic cavity   s_1109)        NaN
# 455                                Facial pain, severe   s_1194)        NaN
# 28    Abdominal pain, radiating to lower or middle p...  s_1846)        NaN
# 897                                           Pruritus    s_254)        NaN
# 953                                     Rovsing's sign   s_1732)        NaN
# 72                                Annular skin lesions   s_1647)        NaN
# 1149                              Vomiting, projectile    s_801)        NaN
# 600                                    Impaired memory    s_316)        NaN
# 334                             Discharge from urethra    s_369)        NaN
# 69                                          Anhidrosis   s_1123)        NaN
# 697                                   Lhermitte's sign   s_1054)        NaN
# 808                                Ovarian enlargement   s_1289)        NaN
# 572                           Hemianopsia bitemporalis    s_814)        NaN
# 818    Pain in both lower limbs, stocking distribution   s_1112)        NaN
# 144                                  Breast tenderness   s_1480)        NaN
# 864                          Paresthesias, symmetrical   s_1068)        NaN
# 1002  Soft lump in inguinal region, enlarging during...  s_1243)        NaN
# 530                          Hallucinations, olfactory    s_684)        NaN
# 1125  Urination while coughing or laughing or during...   s_183)        NaN
# 913                                  Receptive aphasia   s_1029)        NaN
# 494                                          Foot pain    s_578)        NaN
# 799                        Opacified tympanic membrane   s_1107)        NaN
# 124                      Bladder sphincter dysfunction   s_1119)        NaN
# 1075                                          Tinnitus    s_407)        NaN
# 23                              Abdominal pain, pelvic   s_1598)        NaN
# 693                     Leopard-like spots on the skin    s_666)        NaN
# 732        Menstrual period more than three weeks late    s_415)        NaN
# ...                                                 ...      ...        ...
# 646                                    Itching of eyes   s_1563)        NaN
# 283                                     Depressed mood    s_169)        NaN
# 937                          Retinal artery occlusions   s_1418)        NaN
# 750                              Muscle weakness, legs    s_743)        NaN
# 273                           Delusion of guilt or sin    s_768)        NaN
# 167                              Change in handwriting    s_345)        NaN
# 318                     Difficulty in achieving orgasm   s_1574)        NaN
# 490                       Flaccid paresis, symmetrical   s_1080)        NaN
# 951                                   Rossolimo's sign   s_1255)        NaN
# 201                                Clearing the throat   s_1094)        NaN
# 57                         Alcohol withdrawal syndrome    s_818)        NaN
# 15          Abdominal pain, lasting less than two days   s_1840)        NaN
# 621                                   Increased libido    s_421)        NaN
# 782                  Nonstop drinking for several days    s_822)        NaN
# 525                                          Halitosis     s_65)        NaN
# 1087     Toothache, reduced after cold foods or drinks    s_339)        NaN
# 98                       Axillary or inguinal freckles   s_1322)        NaN
# 674                    Joint pain, shoulder, movements   s_1805)        NaN
# 570                                       Hemarthrosis   s_1170)        NaN
# 543          Headache, exacerbated by increased stress   s_1762)        NaN
# 945                                         Rhinophyma   s_1682)        NaN
# 388                            Edema, both lower limbs    s_175)        NaN
# 441                                      Eyelid lesion    s_483)        NaN
# 244                            Cyanosis under the eyes   s_1105)        NaN
# 1123                                   Urinary urgency    s_690)        NaN
# 242                                  Cyanosis, fingers    s_553)        NaN
# 180      Chest pain, radiating between shoulder blades     s_37)        NaN
# 140                                 Bowel incontinence    s_641)        NaN
# 125                         Bleeding after intercourse    s_152)        NaN
# 613                           Inability to pass flatus   s_1551)        NaN
#
#       Unnamed: 3
# 610          NaN
# 210          NaN
# 357          NaN
# 335          NaN
# 455          NaN
# 28           NaN
# 897          NaN
# 953          NaN
# 72           NaN
# 1149         NaN
# 600          NaN
# 334          NaN
# 69           NaN
# 697          NaN
# 808          NaN
# 572          NaN
# 818          NaN
# 144          NaN
# 864          NaN
# 1002         NaN
# 530          NaN
# 1125         NaN
# 913          NaN
# 494          NaN
# 799          NaN
# 124          NaN
# 1075         NaN
# 23           NaN
# 693          NaN
# 732          NaN
# ...          ...
# 646          NaN
# 283          NaN
# 937          NaN
# 750          NaN
# 273          NaN
# 167          NaN
# 318          NaN
# 490          NaN
# 951          NaN
# 201          NaN
# 57           NaN
# 15           NaN
# 621          NaN
# 782          NaN
# 525          NaN
# 1087         NaN
# 98           NaN
# 674          NaN
# 570          NaN
# 543          NaN
# 945          NaN
# 388          NaN
# 441          NaN
# 244          NaN
# 1123         NaN
# 242          NaN
# 180          NaN
# 140          NaN
# 125          NaN
# 613          NaN
#
# [1178 rows x 4 columns]
